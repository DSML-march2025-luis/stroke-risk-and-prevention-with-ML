# %% [markdown]
# <br>
#
# ## General info about stroke
#
#
# ![image.png](attachment:image.png)
#
# <br>
#
#
# Source: https://www.world-stroke.org/assets/CVs/Screenshot_2023-09-06_at_12.57.18.png
#
# <br><br>
#
# ![image-2.png](attachment:image-2.png)
#
# Source: https://www.thehaugengroup.com/wp-content/uploads/2024/02/BEFAST-scaled.jpeg
#
# <br><br>

# %% [markdown]
# ## Probability estimation with `predict_proba()`
#
#
# https://www.google.com/search?q=classification+model+probabilities&sca_esv=e6e4297725472cd8&rlz=1C5CHFA_enES1155ES1155&udm=2&biw=1312&bih=731&ei=-3RfaL33NbD6kdUPyPPUkQE&ved=0ahUKEwj94KH2qJOOAxUwfaQEHcg5NRIQ4dUDCBE&uact=5&oq=classification+model+probabilities&gs_lp=&sclient=img#vhid=oRBohzF1eOqBCM&vssid=mosaic

# %% [markdown]
# <br><br>
#
#
#
# ## Choosing dataset
#
# <br><br>
#
#
# ![image.png](attachment:image.png)
#
#
# (source for this comparison table at the beginning of this conversation: https://chatgpt.com/share/68566ff7-9f0c-8003-85d0-8e82af32c5b4)
#
#
# <br><br>
#
# ![image-3.png](attachment:image-3.png)
#
# <br><br>
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# <br><br>
#
# ![image-4.png](attachment:image-4.png)
#
# <br><br>
#
# ![image-5.png](attachment:image-5.png)
#
# <br><br>
#
# ![image-6.png](attachment:image-6.png)
#
# <br><br>
# <br><br>
