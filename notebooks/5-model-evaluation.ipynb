# %% [markdown]
# # Model Evaluation
#
#
# - 📊 Performance comparison of all models (e.g. tables with metrics)
# - 📉 Plots: ROC curves, precision-recall, calibration curves, etc.
# - ✅ Final model selection rationale
# - 🧪 Evaluation on test set (if not already done)
# - 🧾 Summary of findings and next steps
